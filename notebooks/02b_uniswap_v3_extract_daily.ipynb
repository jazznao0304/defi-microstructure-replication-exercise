# %%
# setup
# %load_ext autoreload
# %autoreload 2
import os, sys, datetime as dt
sys.path.append(os.path.abspath("../src"))

from replication.uniswap_v3_extract_daily import run_uniswap_v3_extract_daily

# %%
"""
# ETH-USDC and ETH-USDT, full window (daily from subgraph)
run_uniswap_v3_extract_daily(labels=["ETH-USDC", "ETH-USDT"])
"""
# Out:
# '\n# ETH-USDC and ETH-USDT, full window (daily from subgraph)\nrun_uniswap_v3_extract_daily(labels=["ETH-USDC", "ETH-USDT"])\n'

# %%
"""
# All pairs, one week's worth
START = int(dt.datetime(2021, 5, 1, tzinfo=dt.timezone.utc).timestamp())
END   = int(dt.datetime(2021, 5, 8, tzinfo=dt.timezone.utc).timestamp())
run_uniswap_v3_extract_daily(start_ts=START, end_ts=END, filename_suffix="_wk", out_subdir="testweek")
"""
# Out:
# '\n# All pairs, one week\'s worth\nSTART = int(dt.datetime(2021, 5, 1, tzinfo=dt.timezone.utc).timestamp())\nEND   = int(dt.datetime(2021, 5, 8, tzinfo=dt.timezone.utc).timestamp())\nrun_uniswap_v3_extract_daily(start_ts=START, end_ts=END, filename_suffix="_wk", out_subdir="testweek")\n'

# %%
# All pairs, full window
run_uniswap_v3_extract_daily()
# Out:
# [OK] ETH-USDC -> 4 v3 pool(s), tiers=[100, 500, 3000, 10000]
# [OK] ETH-USDT -> 4 v3 pool(s), tiers=[100, 500, 3000, 10000]
# [OK] ETH-BTC -> 4 v3 pool(s), tiers=[100, 500, 3000, 10000]
# [OK] LINK-ETH -> 4 v3 pool(s), tiers=[100, 500, 3000, 10000]
# [OK] BTC-USDC -> 4 v3 pool(s), tiers=[100, 500, 3000, 10000]
# [OK] DAI-ETH -> 4 v3 pool(s), tiers=[100, 500, 3000, 10000]
# [OK] MANA-ETH -> 2 v3 pool(s), tiers=[3000, 10000]
# [OK] USDC-USDT -> 4 v3 pool(s), tiers=[100, 500, 3000, 10000]
# [OK] DAI-USDT -> 3 v3 pool(s), tiers=[100, 500, 3000]
# [OK] AAVE-ETH -> 3 v3 pool(s), tiers=[500, 3000, 10000]
# [OK] BAT-ETH -> 3 v3 pool(s), tiers=[500, 3000, 10000]
# [OK] BTC-DAI -> 3 v3 pool(s), tiers=[500, 3000, 10000]
# [OK] CRV-ETH -> 3 v3 pool(s), tiers=[500, 3000, 10000]
# [OK] GRT-ETH -> 2 v3 pool(s), tiers=[3000, 10000]
# [OK] KNC-ETH -> 3 v3 pool(s), tiers=[100, 3000, 10000]
# [OK] REP-ETH -> 2 v3 pool(s), tiers=[3000, 10000]
# [OK] SNX-ETH -> 2 v3 pool(s), tiers=[3000, 10000]
# ...
