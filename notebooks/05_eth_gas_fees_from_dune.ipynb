# %%
# ----------------------------
# Daily ETH gas fees from Dune
# Save under: data/raw/ethereum/gas_fees/eth_gas_fees_daily.parquet
# ----------------------------
from pathlib import Path
import os
import pandas as pd
import numpy as np
from dotenv import load_dotenv
import logging

# (Optional) quiet Dune client logs
# logging.getLogger("dune_client").setLevel(logging.WARNING)

# Dune client
from dune_client.client import DuneClient
from dune_client.query import QueryBase
from dune_client.types import QueryParameter

# ----------------------------
# Config
# ----------------------------
DATA_DIR   = Path("../data")
RAW_DIR    = DATA_DIR / "raw" / "ethereum" / "gas_fees"
RAW_DIR.mkdir(parents=True, exist_ok=True)

OUT_PATH   = RAW_DIR / "eth_gas_fees_daily.parquet"  # single canonical file (overwrites on rerun)
QUERY_ID   = 5697155                                 # Dune query
START_DATE = "2021-02-01 00:00:00"
END_DATE   = "2023-03-01 00:00:00"

# Load API key
load_dotenv("../config/.env")
dune = DuneClient(os.getenv("DUNE_API_KEY"))

# ----------------------------
# Run query
# ----------------------------
q = QueryBase(
    name="Daily ETH gas fees",
    query_id=QUERY_ID,
    params=[
        QueryParameter.date_type(name="start_date", value=START_DATE),
        QueryParameter.date_type(name="end_date",   value=END_DATE),
    ],
)
print("Results available at:", q.url())

fees = dune.run_query_dataframe(q)

# ----------------------------
# Clean types & columns
# ----------------------------
# Dune can return '<nil>' strings; coerce to NaN then cast.
fees = fees.replace({"<nil>": np.nan})

# Parse day to UTC timestamp and also a plain date column for convenience
fees["day"] = pd.to_datetime(fees["day"], utc=True, errors="coerce")
fees["date"] = fees["day"].dt.date

float_cols = [
    "median_base_fee_gwei",
    "median_priority_fee_gwei",
    "median_effective_gas_price_gwei",
    "median_total_fee_gwei",
]
for c in float_cols:
    if c in fees.columns:
        fees[c] = pd.to_numeric(fees[c], errors="coerce")

int_cols = ["n_blocks_with_basefee", "n_blocks", "n_txs"]
for c in int_cols:
    if c in fees.columns:
        fees[c] = pd.to_numeric(fees[c], errors="coerce").astype("Int64")

# Deterministic sort, then save
fees = fees.sort_values("day").reset_index(drop=True)
fees.to_parquet(OUT_PATH, index=False)

# ----------------------------
# Summary
# ----------------------------
print("[ETH Gas Fees] Saved ->", OUT_PATH)
print(f"rows={len(fees):,}  window={fees['date'].min()} → {fees['date'].max()}")
nulls = fees[float_cols + int_cols].isna().mean().mul(100).round(2)
print("[null % by column]")
print(nulls[nulls > 0].to_dict())
# Out:
# 2025-09-11 23:48:06,681 INFO dune_client.api.base executing 5697155 on medium cluster
# Results available at: https://dune.com/queries/5697155?start_date=2021-02-01+00%3A00%3A00&end_date=2023-03-01+00%3A00%3A00
# 2025-09-11 23:48:06,933 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.PENDING (queue position: 84)
# 2025-09-11 23:48:07,977 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.PENDING (queue position: 84)
# 2025-09-11 23:48:09,036 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:48:10,071 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:48:11,127 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:48:12,163 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:48:13,210 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:48:14,260 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:48:15,304 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:48:16,349 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:48:17,380 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:48:18,452 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:48:19,513 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:48:20,566 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:48:21,617 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:48:22,679 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:48:23,728 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:48:24,799 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:48:25,856 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:48:26,921 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:48:27,973 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:48:29,028 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:48:30,095 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:48:31,157 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:48:32,204 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:48:33,247 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:48:34,301 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:48:35,361 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:48:36,419 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:48:37,468 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:48:38,528 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:48:39,579 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:48:40,622 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:48:41,664 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:48:42,730 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:48:43,782 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:48:44,836 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:48:45,896 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:48:46,959 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:48:48,009 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:49:04,243 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:49:05,309 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:49:06,365 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:49:07,439 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:49:08,483 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:49:09,544 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:49:10,594 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:49:11,640 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:49:12,680 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:49:13,757 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:49:14,808 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:49:15,862 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:49:16,899 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:49:17,951 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:49:18,994 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:49:20,047 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:49:21,121 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:49:22,182 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:49:23,242 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:49:24,312 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:49:25,389 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:49:26,464 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:49:27,514 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:49:28,580 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:49:29,633 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:49:30,703 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:49:31,746 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:49:32,797 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:49:33,853 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:49:34,922 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:49:35,981 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:49:37,031 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:49:38,100 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:49:39,158 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:49:40,196 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:49:41,259 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:49:42,313 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:49:43,369 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:49:44,418 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:49:45,463 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:50:01,722 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:50:02,763 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:50:03,807 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:50:04,879 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:50:05,939 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:50:06,996 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:50:08,086 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:50:09,128 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:50:10,181 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:50:11,243 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:50:12,293 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# 2025-09-11 23:50:13,338 INFO dune_client.api.base waiting for query execution 01K4XC01S88S2R8W1TR833199H to complete: ExecutionState.EXECUTING
# [ETH Gas Fees] Saved -> ..\data\raw\ethereum\gas_fees\eth_gas_fees_daily.parquet
# rows=758  window=2021-02-01 → 2023-02-28
# [null % by column]
# {'median_base_fee_gwei': 24.41, 'median_priority_fee_gwei': 24.41, 'median_total_fee_gwei': 24.41}
